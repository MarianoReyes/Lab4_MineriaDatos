# %% [markdown]
# # Sección 1

# %%
import pandas as pd
import matplotlib.pyplot as plt

# cargar el conjunto de datos iris.csv
data = pd.read_csv('iris.csv')

# visualizar los primeros 5 registros del conjunto de datos
print(data.head())
# Out:
#    sepal_length  sepal_width  petal_length  petal_width
# 0           5.1          3.5           1.4          0.2
# 1           4.9          3.0           1.4          0.2
# 2           4.7          3.2           1.3          0.2
# 3           4.6          3.1           1.5          0.2
# 4           5.0          3.6           1.4          0.2

# %% [markdown]
# ### Una vez tenemos el archivo leido procedemos a crear los clusters

# %%
from sklearn.cluster import KMeans

# crear un objeto KMeans con 2 clusters
kmeans = KMeans(n_clusters=2)

# entrenar el modelo de clustering
kmeans.fit(data[['sepal_length', 'sepal_width']])

# asignar una etiqueta de cluster a cada punto
labels = kmeans.predict(data[['sepal_length', 'sepal_width']])

# crear un gráfico de dispersión de longitud del sépalo versus ancho del sépalo, colorizado por etiqueta de cluster
plt.scatter(data['sepal_length'], data['sepal_width'], c=labels)
plt.xlabel('Longitud del Sépalo')
plt.ylabel('Ancho del Sépalo')
plt.show()
# Out:
# C:\Users\Jose\AppData\Roaming\Python\Python39\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(

# %% [markdown]
# ### Como siguiente paso estandarizaremos los datos y volveremos a hacer el paso 2

# %%
from sklearn.preprocessing import StandardScaler

# estandarizar los datos
scaler = StandardScaler()
scaled_data = scaler.fit_transform(data[['sepal_length', 'sepal_width', 'petal_length', 'petal_width']])

# crear un objeto KMeans con 2 clusters
kmeans = KMeans(n_clusters=2)

# entrenar el modelo de clustering
kmeans.fit(scaled_data)

# asignar una etiqueta de cluster a cada punto
labels = kmeans.predict(scaled_data)

# crear un gráfico de dispersión de longitud del sépalo versus ancho del sépalo, colorizado por etiqueta de cluster
plt.scatter(data['sepal_length'], data['sepal_width'], c=labels)
plt.xlabel('Longitud del Sépalo')
plt.ylabel('Ancho del Sépalo')
plt.show()
# Out:
# C:\Users\Jose\AppData\Roaming\Python\Python39\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(

# %% [markdown]
# ### Usamos el método del codo para conocer los clusters ideales

# %%
# calcular la suma de las distancias al cuadrado para diferentes valores de k
sum_of_squared_distances = []
K = range(1,11)
for k in K:
    kmeans = KMeans(n_clusters=k)
    kmeans.fit(scaled_data)
    sum_of_squared_distances.append(kmeans.inertia_)

# graficar la suma de las distancias al cuadrado versus k
plt.plot(K, sum_of_squared_distances, 'bx-')
plt.xlabel('k')
plt.ylabel('Suma de las distancias al cuadrado')
plt.title('Método del codo para encontrar el número óptimo de clusters')
plt.show()
# Out:
# C:\Users\Jose\AppData\Roaming\Python\Python39\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\Jose\AppData\Roaming\Python\Python39\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\Jose\AppData\Roaming\Python\Python39\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# ...

# %% [markdown]
# ### Creamos diferentes gráficas basándonos en el número de clusters que se ajusten mejor a los datos

# %%
# crear un objeto KMeans con 2 clusters
kmeans = KMeans(n_clusters=2)

# entrenar el modelo de clustering
kmeans.fit(scaled_data)

# asignar una etiqueta de cluster a cada punto
labels = kmeans.predict(scaled_data)

# crear un gráfico de dispersión de longitud del sépalo versus ancho del sépalo, colorizado por etiqueta de cluster
plt.scatter(data['sepal_length'], data['sepal_width'], c=labels)
plt.xlabel('Longitud del Sépalo')
plt.ylabel('Ancho del Sépalo')
plt.title('2 clusters')
plt.show()

# crear un objeto KMeans con 3 clusters
kmeans = KMeans(n_clusters=3)

# entrenar el modelo de clustering
kmeans.fit(scaled_data)

# asignar una etiqueta de cluster a cada punto
labels = kmeans.predict(scaled_data)

# crear un gráfico de dispersión de longitud del sépalo versus ancho del sépalo, colorizado por etiqueta de cluster
plt.scatter(data['sepal_length'], data['sepal_width'], c=labels)
plt.xlabel('Longitud del Sépalo')
plt.ylabel('Ancho del Sépalo')
plt.title('3 clusters')
plt.show()

# crear un objeto KMeans con 4 clusters
kmeans = KMeans(n_clusters=4)

# entrenar el modelo de clustering
kmeans.fit(scaled_data)

# asignar una etiqueta de cluster a cada punto
labels = kmeans.predict(scaled_data)

# crear un gráfico de dispersión de longitud del sépalo versus ancho del sépalo, colorizado por etiqueta de cluster
plt.scatter(data['sepal_length'], data['sepal_width'], c=labels)
plt.xlabel('Longitud del Sépalo')
plt.ylabel('Ancho del Sépalo')
plt.title('4 clusters')
plt.show()
# Out:
# C:\Users\Jose\AppData\Roaming\Python\Python39\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\Jose\AppData\Roaming\Python\Python39\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\Jose\AppData\Roaming\Python\Python39\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(

# %% [markdown]
# ### Comparamos con los datos reales

# %%
import pandas as pd
import matplotlib.pyplot as plt

# cargar datos
iris = pd.read_csv("iris-con-respuestas.csv")

# mapear especies a valores numéricos
species_to_label = {"setosa": 0, "versicolor": 1, "virginica": 2}
iris["label"] = iris["species"].map(species_to_label)

# gráfico de dispersión
plt.scatter(iris["sepal_length"], iris["sepal_width"], c=iris["label"], cmap="viridis")
plt.xlabel("sepal length")
plt.ylabel("sepal width")
plt.show()

# %% [markdown]
# ### ¿Funcionó el clustering con la forma del sépalo?
#
# Sí, gracias al método del codo el clustering con la forma del sépalo funcionó bastante bien cuando se usó un número 3 en clusters ya que los clusters resultantes corresponden bastante bien con las tres especies de iris verdaderas.

# %% [markdown]
# # Sección 2

# %%
import pandas as pd
import matplotlib.pyplot as plt

# cargar el conjunto de datos iris.csv
data = pd.read_csv('iris.csv')

# %% [markdown]
# ### Una vez tenemos el archivo leido procedemos a crear los clusters de pétalos

# %%
from sklearn.cluster import KMeans

# crear un objeto KMeans con 2 clusters
kmeans = KMeans(n_clusters=2)

# entrenar el modelo de clustering
kmeans.fit(data[['petal_length', 'petal_width']])

# asignar una etiqueta de cluster a cada punto
labels = kmeans.predict(data[['petal_length', 'petal_width']])

# crear un gráfico de dispersión de longitud del sépalo versus ancho del sépalo, colorizado por etiqueta de cluster
plt.scatter(data['petal_length'], data['petal_width'], c=labels)
plt.xlabel('Longitud del Pétalo')
plt.ylabel('Ancho del Pétalo')
plt.show()
# Out:
# C:\Users\Jose\AppData\Roaming\Python\Python39\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(

# %% [markdown]
# ### Como siguiente paso estandarizaremos los datos y volveremos a hacer el paso 2

# %%
from sklearn.preprocessing import StandardScaler

# estandarizar los datos
scaler = StandardScaler()
scaled_data = scaler.fit_transform(data[['sepal_length', 'sepal_width', 'petal_length', 'petal_width']])

# crear un objeto KMeans con 2 clusters
kmeans = KMeans(n_clusters=2)

# entrenar el modelo de clustering
kmeans.fit(scaled_data)

# asignar una etiqueta de cluster a cada punto
labels = kmeans.predict(scaled_data)

# crear un gráfico de dispersión de longitud del sépalo versus ancho del sépalo, colorizado por etiqueta de cluster
plt.scatter(data['petal_length'], data['petal_width'], c=labels)
plt.xlabel('Longitud del Pétalo')
plt.ylabel('Ancho del Pétalo')
plt.show()
# Out:
# C:\Users\Jose\AppData\Roaming\Python\Python39\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(

# %% [markdown]
# ### Usamos el método del codo para conocer los clusters ideales

# %%
# calcular la suma de las distancias al cuadrado para diferentes valores de k
sum_of_squared_distances = []
K = range(1,11)
for k in K:
    kmeans = KMeans(n_clusters=k)
    kmeans.fit(scaled_data)
    sum_of_squared_distances.append(kmeans.inertia_)

# graficar la suma de las distancias al cuadrado versus k
plt.plot(K, sum_of_squared_distances, 'bx-')
plt.xlabel('k')
plt.ylabel('Suma de las distancias al cuadrado')
plt.title('Método del codo para encontrar el número óptimo de clusters')
plt.show()
# Out:
# C:\Users\Jose\AppData\Roaming\Python\Python39\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\Jose\AppData\Roaming\Python\Python39\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\Jose\AppData\Roaming\Python\Python39\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# ...

# %% [markdown]
# ### Creamos diferentes gráficas basándonos en el número de clusters que se ajusten mejor a los datos

# %%
# crear un objeto KMeans con 2 clusters
kmeans = KMeans(n_clusters=2)

# entrenar el modelo de clustering
kmeans.fit(scaled_data)

# asignar una etiqueta de cluster a cada punto
labels = kmeans.predict(scaled_data)

# crear un gráfico de dispersión de longitud del sépalo versus ancho del sépalo, colorizado por etiqueta de cluster
plt.scatter(data['petal_length'], data['petal_width'], c=labels)
plt.xlabel('Longitud del Pétalo')
plt.ylabel('Ancho del Pétalo')
plt.title('2 clusters')
plt.show()

# crear un objeto KMeans con 3 clusters
kmeans = KMeans(n_clusters=3)

# entrenar el modelo de clustering
kmeans.fit(scaled_data)

# asignar una etiqueta de cluster a cada punto
labels = kmeans.predict(scaled_data)

# crear un gráfico de dispersión de longitud del sépalo versus ancho del sépalo, colorizado por etiqueta de cluster
plt.scatter(data['petal_length'], data['petal_width'], c=labels)
plt.xlabel('Longitud del Pétalo')
plt.ylabel('Ancho del Pétalo')
plt.title('3 clusters')
plt.show()

# crear un objeto KMeans con 4 clusters
kmeans = KMeans(n_clusters=4)

# entrenar el modelo de clustering
kmeans.fit(scaled_data)

# asignar una etiqueta de cluster a cada punto
labels = kmeans.predict(scaled_data)

# crear un gráfico de dispersión de longitud del sépalo versus ancho del sépalo, colorizado por etiqueta de cluster
plt.scatter(data['petal_length'], data['petal_width'], c=labels)
plt.xlabel('Longitud del Pétalo')
plt.ylabel('Ancho del Pétalo')
plt.title('4 clusters')
plt.show()
# Out:
# C:\Users\Jose\AppData\Roaming\Python\Python39\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\Jose\AppData\Roaming\Python\Python39\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\Jose\AppData\Roaming\Python\Python39\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(

# %% [markdown]
# ### Comparamos con los datos reales

# %%
import pandas as pd
import matplotlib.pyplot as plt

# cargar datos
iris = pd.read_csv("iris-con-respuestas.csv")

# mapear especies a valores numéricos
species_to_label = {"setosa": 0, "versicolor": 1, "virginica": 2}
iris["label"] = iris["species"].map(species_to_label)

# gráfico de dispersión
plt.scatter(iris["petal_length"], iris["petal_width"], c=iris["label"], cmap="viridis")
plt.xlabel("Longitud del Pétalo")
plt.ylabel("Ancho del Pétalo")
plt.show()

# %% [markdown]
# ### ¿Funcionó el clustering con la forma del pétalo?
#
# Sí, el clustering con la forma del pétalo funcionó bastante bien también cuando se usó un número 3 en clusters gracias al método del codo, ya que los clusters resultantes corresponden bastante bien con las tres especies de iris verdaderas.

# %% [markdown]
# # Sección 3

# %%
pip install kneed
# Out:
# Note: you may need to restart the kernel to use updated packages.
# ...
# WARNING: Ignoring invalid distribution -ip (c:\python39\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\python39\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (c:\python39\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\python39\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (c:\python39\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\python39\lib\site-packages)

# %%
import pandas as pd
from sklearn.cluster import KMeans
from kneed import KneeLocator
import matplotlib.pyplot as plt

# cargar datos
iris = pd.read_csv("iris.csv")

# estandarizar datos
iris_std = (iris - iris.mean()) / iris.std()

# calcular SSE para diferentes valores de k
sse = []
for k in range(1, 11):
    kmeans = KMeans(n_clusters=k, random_state=42)
    kmeans.fit(iris_std)
    sse.append(kmeans.inertia_)

# encontrar punto de codo
kl = KneeLocator(range(1, 11), sse, curve="convex", direction="decreasing")
knee = kl.elbow

# graficar la suma de la distancia al cuadrado vs k y el punto de codo
plt.plot(range(1, 11), sse, marker="o")
plt.xlabel("k")
plt.ylabel("Suma de la distancia al cuadrado")
plt.vlines(knee, plt.ylim()[0], plt.ylim()[1], linestyles="--")
plt.annotate("Punto de Codo", xy=(knee, sse[knee-1]), xytext=(4, 100), textcoords="offset points", fontsize=10, arrowprops=dict(facecolor="black", arrowstyle="->"))
plt.show()

print(f"El número óptimo de clusters encontrado con knee es: {knee}")
# Out:
# C:\Users\Jose\AppData\Roaming\Python\Python39\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\Jose\AppData\Roaming\Python\Python39\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\Jose\AppData\Roaming\Python\Python39\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# ...

# %% [markdown]
# Con esto podemos concluir que el número encontrado con el método del codo fue el acertado y el método de clustering se realizó correctamente :D !
